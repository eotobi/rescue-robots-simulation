# %%
import mesa
from rescue_robots.agents import FirstAidRobot, ExplorerDrone, Patient
from rescue_robots.model import RescueRobots

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec

# %matplotlib inline

# %%
rescueRobots = RescueRobots()

# %%
#Reduce or increase the step_count to get less or more steps for collecting simulation data
step_count=20

#res = pd.DataFrame([])
df_new = pd.DataFrame([])
for i in range(step_count):
    rescueRobots.step()
    data = rescueRobots.grid_stats(i)
    res = pd.concat([res, df_new])
res.plot(x='level_0',y='level_1',kind='scatter')
plt.ylabel('Y-Coordinate')
plt.xlabel('X-Coordinate')
plt.title('Locations Easily Accessible to Aerial Drones and Firstaid Terrain Robots. Patients in these locations have higher chances of attention from robots')
plt.show()

# %%
res2 = rescueRobots.datacollector.get_model_vars_dataframe()
res3 = rescueRobots.datacollector.get_agent_vars_dataframe()
print(res3)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
res2.plot(y=['Patient','FirstAid Robot','Explorer Drone'],kind='line')
plt.ylabel('Number of Patients')
plt.xlabel('Time')
plt.title('Final Number of Agents in the Mountain to Time Elapse')
plt.show()
